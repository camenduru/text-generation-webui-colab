# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/camenduru/text-generation-webui-colab/blob/main/alpaca-7b-native-4bit.ipynb)

# %%
# %cd /content
# !apt-get -y install -qq aria2

# !git clone -b v1.0 https://github.com/camenduru/text-generation-webui
# %cd /content/text-generation-webui
# !pip install -r requirements.txt

# !mkdir /content/text-generation-webui/repositories
# %cd /content/text-generation-webui/repositories
# !git clone -b v1.0 https://github.com/camenduru/GPTQ-for-LLaMa.git
# %cd GPTQ-for-LLaMa
# !python setup_cuda.py install

# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/alpaca-7b-native-4bit/raw/main/config.json -d /content/text-generation-webui/models/alpaca-7b-native-4bit -o config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/alpaca-7b-native-4bit/raw/main/generation_config.json -d /content/text-generation-webui/models/alpaca-7b-native-4bit -o generation_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/alpaca-7b-native-4bit/raw/main/special_tokens_map.json -d /content/text-generation-webui/models/alpaca-7b-native-4bit -o special_tokens_map.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/alpaca-7b-native-4bit/resolve/main/tokenizer.model -d /content/text-generation-webui/models/alpaca-7b-native-4bit -o tokenizer.model
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/alpaca-7b-native-4bit/raw/main/tokenizer_config.json -d /content/text-generation-webui/models/alpaca-7b-native-4bit -o tokenizer_config.json
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/4bit/alpaca-7b-native-4bit/resolve/main/alpaca7b-4bit.pt -d /content/text-generation-webui/models/alpaca-7b-native-4bit -o alpaca7b-4bit.pt

# %cd /content/text-generation-webui
# !python server.py --share --chat --wbits 4 --groupsize 128
